# %% [markdown]
# <a href="https://colab.research.google.com/github/Troyanovsky/Local-LLM-comparison/blob/main/WizardLM_Uncensored_Falcon_7B_GPTQ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## WizardLM-Uncensored-Falcon-7B-GPTQ WebUI
# 1. Run the following cell, takes ~5 min
# 2. Click the gradio link at the bottom
# 3. In Chat settings - Instruction Template: choose WizardLM

# %%
# %cd /content
# !apt-get -y install -qq aria2

# !git clone -b V1.1 https://github.com/Troyanovsky/text-generation-webui
# %cd /content/text-generation-webui
# !pip install -r requirements.txt
# !pip install -U gradio==3.32.0

# !mkdir /content/text-generation-webui/repositories
# %cd /content/text-generation-webui/repositories
# !git clone https://github.com/PanQiWei/AutoGPTQ
# %cd AutoGPTQ
# !pip install .
# !pip install einops

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/TheBloke/WizardLM-Uncensored-Falcon-7B-GPTQ/resolve/main/config.json -d /content/text-generation-webui/models/WizardLM-Uncensored-Falcon-7B-GPTQ -o config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/TheBloke/WizardLM-Uncensored-Falcon-7B-GPTQ/resolve/main/generation_config.json -d /content/text-generation-webui/models/WizardLM-Uncensored-Falcon-7B-GPTQ -o generation_config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/TheBloke/WizardLM-Uncensored-Falcon-7B-GPTQ/resolve/main/special_tokens_map.json -d /content/text-generation-webui/models/WizardLM-Uncensored-Falcon-7B-GPTQ -o special_tokens_map.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/TheBloke/WizardLM-Uncensored-Falcon-7B-GPTQ/resolve/main/configuration_RW.py -d /content/text-generation-webui/models/WizardLM-Uncensored-Falcon-7B-GPTQ -o configuration_RW.py
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/TheBloke/WizardLM-Uncensored-Falcon-7B-GPTQ/resolve/main/gptq_model-4bit-64g.safetensors -d /content/text-generation-webui/models/WizardLM-Uncensored-Falcon-7B-GPTQ -o gptq_model-4bit-64g.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/TheBloke/WizardLM-Uncensored-Falcon-7B-GPTQ/resolve/main/modelling_RW.py -d /content/text-generation-webui/models/WizardLM-Uncensored-Falcon-7B-GPTQ -o modelling_RW.py
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/TheBloke/WizardLM-Uncensored-Falcon-7B-GPTQ/resolve/main/quantize_config.json -d /content/text-generation-webui/models/WizardLM-Uncensored-Falcon-7B-GPTQ -o quantize_config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/TheBloke/WizardLM-Uncensored-Falcon-7B-GPTQ/resolve/main/tokenizer.json -d /content/text-generation-webui/models/WizardLM-Uncensored-Falcon-7B-GPTQ -o tokenizer.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/TheBloke/WizardLM-Uncensored-Falcon-7B-GPTQ/resolve/main/tokenizer_config.json -d /content/text-generation-webui/models/WizardLM-Uncensored-Falcon-7B-GPTQ -o tokenizer_config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/TheBloke/WizardLM-Uncensored-Falcon-7B-GPTQ/resolve/main/zero_to_fp32.py -d /content/text-generation-webui/models/WizardLM-Uncensored-Falcon-7B-GPTQ -o zero_to_fp32.py

# %cd /content/text-generation-webui
# !python server.py --share --chat --autogptq --trust-remote-code
# Out:
# /content
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 122542 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.15.0-1ubuntu0.2_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.15.0-1ubuntu0.2) ...
# Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.35.0-1build1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.35.0-1build1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.35.0-1build1_amd64.deb ...
# Unpacking aria2 (1.35.0-1build1) ...
# Setting up libc-ares2:amd64 (1.15.0-1ubuntu0.2) ...
# Setting up libaria2-0:amd64 (1.35.0-1build1) ...
# Setting up aria2 (1.35.0-1build1) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Cloning into 'text-generation-webui'...
# remote: Enumerating objects: 7938, done.
# remote: Counting objects: 100% (156/156), done.
# ...
