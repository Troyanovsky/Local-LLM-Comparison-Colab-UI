# %% [markdown]
# <a href="https://colab.research.google.com/github/Troyanovsky/Local-LLM-comparison/blob/main/guanaco_13B_GPTQ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !apt-get -y install -qq aria2

# !git clone -b V1.0 https://github.com/Troyanovsky/text-generation-webui
# %cd /content/text-generation-webui
# !pip install -r requirements.txt
# !pip install -U gradio==3.32.0

# !mkdir /content/text-generation-webui/repositories
# %cd /content/text-generation-webui/repositories
# !git clone -b V1.0 https://github.com/Troyanovsky/GPTQ-for-LLaMa
# %cd GPTQ-for-LLaMa
# !python setup_cuda.py install

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/TheBloke/guanaco-13B-GPTQ/resolve/main/config.json -d /content/text-generation-webui/models/guanaco-13B-GPTQ -o config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/TheBloke/guanaco-13B-GPTQ/resolve/main/generation_config.json -d /content/text-generation-webui/models/guanaco-13B-GPTQ -o generation_config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/TheBloke/guanaco-13B-GPTQ/resolve/main/special_tokens_map.json -d /content/text-generation-webui/models/guanaco-13B-GPTQ -o special_tokens_map.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/TheBloke/guanaco-13B-GPTQ/resolve/main/tokenizer.model -d /content/text-generation-webui/models/guanaco-13B-GPTQ -o tokenizer.model
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/TheBloke/guanaco-13B-GPTQ/resolve/main/tokenizer_config.json -d /content/text-generation-webui/models/guanaco-13B-GPTQ -o tokenizer_config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/TheBloke/guanaco-13B-GPTQ/resolve/main/Guanaco-13B-GPTQ-4bit-128g.no-act-order.safetensors -d /content/text-generation-webui/models/guanaco-13B-GPTQ -o Guanaco-13B-GPTQ-4bit-128g.no-act-order.safetensors

# %cd /content/text-generation-webui
# !python server.py --share --chat --wbits 4 --groupsize 128 --model_type llama
# Out:
# /content
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 122545 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.15.0-1ubuntu0.2_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.15.0-1ubuntu0.2) ...
# Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.35.0-1build1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.35.0-1build1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.35.0-1build1_amd64.deb ...
# Unpacking aria2 (1.35.0-1build1) ...
# Setting up libc-ares2:amd64 (1.15.0-1ubuntu0.2) ...
# Setting up libaria2-0:amd64 (1.35.0-1build1) ...
# Setting up aria2 (1.35.0-1build1) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Cloning into 'text-generation-webui'...
# remote: Enumerating objects: 7623, done.
# remote: Counting objects: 100% (4014/4014), done.
# ...
