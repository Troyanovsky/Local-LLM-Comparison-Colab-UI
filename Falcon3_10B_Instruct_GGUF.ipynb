# %% [markdown]
# <a href="https://colab.research.google.com/github/Troyanovsky/Local-LLM-Comparison-Colab-UI/blob/main/Falcon3_10B_Instruct_GGUF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Falcon3-10B-Instruct-GGUF WebUI
#
# 1. Run the following cell, takes ~5 min
# (You may need to confirm to proceed by typing "Y")
# 2. Click the gradio link at the bottom
# 3. Template: Falcon?
#
#
# Quantized model: https://huggingface.co/tiiuae/Falcon3-10B-Instruct-GGUF
#
# Original model: https://huggingface.co/tiiuae/Falcon3-10B-Instruct
#
# Want to try other local LLMs? Check out this repo: https://github.com/Troyanovsky/Local-LLM-Comparison-Colab-UI/

# %%
# %cd /content
# !apt-get -y install -qq aria2
# !pip install torch==2.2.2 torchvision==0.17.2 torchaudio==2.2.2 --index-url https://download.pytorch.org/whl/cu121

# !git clone -b V20250121 https://github.com/Troyanovsky/text-generation-webui
# %cd /content/text-generation-webui
# !pip install -r requirements.txt

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/tiiuae/Falcon3-10B-Instruct-GGUF/resolve/main/Falcon3-10B-Instruct-q5_k_m.gguf?download=true -d /content/text-generation-webui/models/ -o Falcon3-10B-Instruct-q5_k_m.gguf
# %cd /content/text-generation-webui
# !python server.py --share --n-gpu-layers 100000 --model Falcon3-10B-Instruct-q5_k_m.gguf --n_ctx 2048
# Out:
# /content
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 124565 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.18.1-1ubuntu0.22.04.3_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.36.0-1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.36.0-1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.36.0-1_amd64.deb ...
# Unpacking aria2 (1.36.0-1) ...
# Setting up libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Setting up libaria2-0:amd64 (1.36.0-1) ...
# Setting up aria2 (1.36.0-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# ...
