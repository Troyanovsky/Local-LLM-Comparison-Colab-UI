# %% [markdown]
# <a href="https://colab.research.google.com/github/Troyanovsky/Local-LLM-Comparison-Colab-UI/blob/main/Panda_7B_v0_1_GGUF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Panda-7B-v0.1-GGUF WebUI
#
# 1. Run the following cell, takes ~5 min
# (You may need to confirm to proceed by typing "Y")
# 2. Pick the version you need from one of the last two cells and only run that cell.
# 3. Click the gradio link at the bottom
# 4. In Chat settings - Instruction Template: Unknown
#
# ```
# {prompt}
# ```

# %%
# %cd /content
# !apt-get -y install -qq aria2

# !git clone -b V20231221 https://github.com/Troyanovsky/text-generation-webui
# %cd /content/text-generation-webui
# !pip install -r requirements.txt
# !pip install -U gradio==3.50.2

# !pip uninstall -y llama-cpp-python -y
# !CMAKE_ARGS="-DLLAMA_CUBLAS=on" FORCE_CMAKE=1 pip install llama-cpp-python --no-cache-dir

# !pip uninstall flash-attn -y
# !pip install --no-build-isolation flash-attn==2.3.4

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/TheBloke/Panda-7B-v0.1-GGUF/resolve/main/panda-7b-v0.1.Q5_K_M.gguf?download=true -d /content/text-generation-webui/models/ -o panda-7b-v0.1.Q5_K_M.gguf

# %cd /content/text-generation-webui
# !python server.py --share --n-gpu-layers 1000000 --model panda-7b-v0.1.Q5_K_M.gguf
# Out:
# /content/text-generation-webui
# 10:43:46-207364 INFO     Starting Text generation web UI
# 10:43:46-279864 INFO     Loading panda-7b-v0.1.Q5_K_M.gguf
# 10:43:46-405687 INFO     llama.cpp weights detected: models/panda-7b-v0.1.Q5_K_M.gguf
# ggml_init_cublas: GGML_CUDA_FORCE_MMQ:   yes
# ggml_init_cublas: CUDA_USE_TENSOR_CORES: no
# ggml_init_cublas: found 1 CUDA devices:
#   Device 0: Tesla T4, compute capability 7.5
# llama_model_loader: loaded meta data with 23 key-value pairs and 291 tensors from models/panda-7b-v0.1.Q5_K_M.gguf (version GGUF V3 (latest))
# llama_model_loader: - tensor    0:                token_embd.weight q5_K     [  4096, 32000,     1,     1 ]
# llama_model_loader: - tensor    1:           blk.0.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor    2:            blk.0.ffn_down.weight q6_K     [ 14336,  4096,     1,     1 ]
# ...
